# %% [markdown]
# **Image Processing: A2**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !gdown --id '1r8RwsowdkEZFgjOqMRTB4qqmwU_eSfOI' --output jigsaw.jpg
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1r8RwsowdkEZFgjOqMRTB4qqmwU_eSfOI
# To: /content/jigsaw.jpg
# 100% 43.2k/43.2k [00:00<00:00, 92.2MB/s]

# %%
from PIL import Image
im = Image.open("../content/jigsaw.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=797x421 at 0x7F939E1A66E0>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = np.array(im)
print(image)
# Out:
# [[[ 22  20  42]
#   [ 22  20  42]
#   [ 23  21  43]
#   ...
#   [182 188  82]
#   [182 188  82]
#   [182 188  82]]
#
#  [[ 25  23  45]
#   [ 25  23  45]
#   [ 25  23  45]
#   ...
#   [182 188  82]
#   [182 188  82]
#   [182 188  82]]
#
#  [[ 28  26  48]
#   [ 27  25  47]
#   [ 27  25  47]
#   ...
#   [182 188  82]
#   [182 188  82]
#   [182 188  82]]
#
#  ...
#
#  [[222 214 203]
#   [234 226 215]
#   [226 218 207]
#   ...
#   [ 71  65  53]
#   [ 74  68  54]
#   [ 76  68  55]]
#
#  [[245 237 226]
#   [243 235 224]
#   [216 208 197]
#   ...
#   [ 76  70  58]
#   [ 75  69  55]
#   [ 75  67  54]]
#
#  [[201 193 182]
#   [216 208 197]
#   [214 206 195]
#   ...
#   [ 81  75  63]
#   [ 77  71  57]
#   [ 75  67  54]]]

# %%
plt.imshow(im)

# %%
image.shape
# Out:
# (421, 797, 3)

# %%
plt.imshow(image[300:400, 300:400])
plt.show()

# %%
image[370:421,370:797] = cv2.flip(image[370:421,370:797],0)
plt.imshow(image)

# %%
plt.imshow(image[200:300,510:516])

# %%
plt.imshow(image[200:300,695:705])

# %%
plt.imshow(image[145:155,550:650])

# %%
plt.imshow(image[320:340,550:650])

# %%
image[150:330,515:700] = cv2.flip(image[150:330,515:700],1)
plt.imshow(image)

# %%
image[198:201]

# %% [markdown]
# Location of pink contour is at 200.

# %%
plt.imshow(image[400:420,0:160])

# %%
plt.imshow(image[250:400,185:195])

# %%
x = image[200:410,0:190]
plt.imshow(x)

# %%
y = image[0:200,0:190]
plt.imshow(y)

# %%
i=image

# %%
i[200:410,0:190]=cv2.flip(i[200:410,0:190],0)
plt.imshow(i)

# %%
import copy
x = copy.deepcopy(image[200:410,0:190])
y = copy.deepcopy(image[0:200,0:190])
image[0:210,0:190]=x
image[200:400,0:190]=y

plt.imshow(image)

# %%
image[0:200,0:190] = cv2.flip(image[0:200,0:190],0)
plt.imshow(image)

# %%
z = copy.deepcopy(image[400:410,0:190])
f = copy.deepcopy(image[0:200,0:190])
image[0:10,0:190]=z
image[10:210,0:190]=f
plt.imshow(image)
