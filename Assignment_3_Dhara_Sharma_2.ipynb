# %%
from google.colab import drive
drive.mount('/content/drive')

cctv1 = '/content/drive/MyDrive/Assignment_3_images/cctv1.JPG'
cctv2 = '/content/drive/MyDrive/Assignment_3_images/cctv2.JPG'
cctv3 = '/content/drive/MyDrive/Assignment_3_images/cctv3.JPG'
cctv4 = '/content/drive/MyDrive/Assignment_3_images/cctv4.JPG'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

c1 = cv2.imread(cctv1, cv2.IMREAD_GRAYSCALE)
c2 = cv2.imread(cctv2, cv2.IMREAD_GRAYSCALE)
c3 = cv2.imread(cctv3, cv2.IMREAD_GRAYSCALE)
c4 = cv2.imread(cctv4, cv2.IMREAD_GRAYSCALE)
cv2_imshow(c2)
# Out:
# <PIL.Image.Image image mode=L size=1121x737 at 0x7F8131CB06A0>

# %%
i = input("Enter the image to be processed")
# Out:
# Enter the image to be processed2

# %%
name = "c{}".format(2)
if name in locals():
  var = locals()[name]
  clahe = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(10, 10)) #Adaptive Histogram Equalization to prevent noise amplification
  equalized = clahe.apply(var)
  brightened_image = cv2.add(equalized, 10)# brightening the image
  cv2_imshow(brightened_image)
else:
  print("Image not found")
# Out:
# <PIL.Image.Image image mode=L size=1121x737 at 0x7F8132907C40>
